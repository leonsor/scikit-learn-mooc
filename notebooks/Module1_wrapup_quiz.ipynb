# %%
import pandas as pd
ames_housing = pd.read_csv("../datasets/ames_housing_no_missing.csv")

target_name = "SalePrice"
data, target = ames_housing.drop(columns=target_name), ames_housing[target_name]
target = (target > 200_000).astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  Grvl      Reg
# 1          20       RL         80.0     9600   Pave  Grvl      Reg
# 2          60       RL         68.0    11250   Pave  Grvl      IR1
# 3          70       RL         60.0     9550   Pave  Grvl      IR1
# 4          60       RL         84.0    14260   Pave  Grvl      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0     Gd  MnPrv
# 1         Lvl    AllPub       FR2  ...           0        0     Gd  MnPrv
# 2         Lvl    AllPub    Inside  ...           0        0     Gd  MnPrv
# 3         Lvl    AllPub    Corner  ...           0        0     Gd  MnPrv
# 4         Lvl    AllPub       FR2  ...           0        0     Gd  MnPrv
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
data.shape[1]
# Out:
# 79

# %%
numerical_features = [
  "LotFrontage", "LotArea", "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2",
  "BsmtUnfSF", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "LowQualFinSF",
  "GrLivArea", "BedroomAbvGr", "KitchenAbvGr", "TotRmsAbvGrd", "Fireplaces",
  "GarageCars", "GarageArea", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch",
  "3SsnPorch", "ScreenPorch", "PoolArea", "MiscVal",
]
data_numeric = data[numerical_features]
data_numeric.head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  ...  Fireplaces  GarageCars  \
# 0          856       856       854             0  ...           0           2
# 1         1262      1262         0             0  ...           1           2
# 2          920       920       866             0  ...           1           2
# 3          756       961       756             0  ...           1           3
# 4         1145      1145      1053             0  ...           1           3
#
# ...

# %%
from sklearn.model_selection import train_test_split
data_train, data_test, target_train, target_test = train_test_split(data_numeric, target, random_state=42)

# %%
data_train.describe()
# Out:
#        LotFrontage        LotArea   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1095.000000    1095.000000  1095.000000  1095.000000  1095.000000
# mean     70.331499   10747.046575   103.369627   448.178082    43.790868
# std      22.798200   11065.878057   171.330636   457.898505   153.896464
# min      21.000000    1300.000000     0.000000     0.000000     0.000000
# 25%      60.000000    7589.000000     0.000000     0.000000     0.000000
# 50%      70.049958    9600.000000     0.000000   387.000000     0.000000
# 75%      79.000000   11700.000000   165.500000   724.000000     0.000000
# max     313.000000  215245.000000  1378.000000  5644.000000  1127.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  ...  \
# count  1095.000000   1095.00000  1095.000000  1095.000000   1095.000000  ...
# mean    568.794521   1060.76347  1170.582648   354.767123      5.863927  ...
# std     444.865511    443.87948   386.930314   440.752719     48.961376  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

model = make_pipeline(StandardScaler(), LogisticRegression())

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
model.fit(data_train, target_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
score= model.score(data_test, target_test)
score
# Out:
# 0.9013698630136986

# %%
from sklearn.model_selection import cross_validate
cv_score = cross_validate(model, data_numeric, target, cv=10)
cv_score

# %%
score=cv_score["test_score"]
print("The mean cross-validation accuracy is: "
f"{score.mean():.3f} +/- {score.std():.3f}")
# Out:
# The mean cross-validation accuracy is: 0.892 +/- 0.013

# %% [markdown]
# ## Question 6

# %%
from sklearn.compose import make_column_selector as selector

#numerical_columns_selector = selector(dtype_exclude=object)
categorical_columns_selector = selector(dtype_include=object)
numerical_columns = numerical_features # numerical_columns_selector(data)
categorical_columns = categorical_columns_selector(data)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

numerical_preprocessor = StandardScaler()
categorical_preprocessor = OneHotEncoder(handle_unknown="ignore")

preprocessor = ColumnTransformer([
    ('categorical', categorical_preprocessor, categorical_columns), # creates new catagorical preprocessor
    ('standard_scaler', numerical_preprocessor, numerical_columns)]) 
    # remainder="passthrough")

model6 = make_pipeline(preprocessor, LogisticRegression(max_iter=500))

cv_results6 = cross_validate(model6, data, target, cv=10)
cv_results6
# Out:
# {'fit_time': array([0.0649991 , 0.06900287, 0.06099582, 0.06203485, 0.05700183,
#         0.07096601, 0.05899787, 0.05499458, 0.05599928, 0.05900025]),
#  'score_time': array([0.00599933, 0.00600219, 0.00599885, 0.00597954, 0.00499964,
#         0.00600052, 0.00603652, 0.00500154, 0.0050025 , 0.00599861]),
#  'test_score': array([0.95205479, 0.9109589 , 0.90410959, 0.92465753, 0.89041096,
#         0.95890411, 0.87671233, 0.89041096, 0.94520548, 0.90410959])}

# %%
scores6 = cv_results6["test_score"]

print("The mean cross_validation accuracy for OneHot encoded Categoricals and scaled integers is: "
    f"{scores6.mean():.3f} +/- {scores6.std():.3f} ")
# Out:
# The mean cross_validation accuracy for OneHot encoded Categoricals and scaled integers is: 0.916 +/- 0.027

# %%
score
# Out:
# array([0.9109589 , 0.89041096, 0.9109589 , 0.88356164, 0.90410959,
#        0.88356164, 0.88356164, 0.87671233, 0.89726027, 0.87671233])

# %%
print(score)
# Out:
# [0.9109589  0.89041096 0.9109589  0.88356164 0.90410959 0.88356164
#  0.88356164 0.87671233 0.89726027 0.87671233]

# %%
print(score[0])
# Out:
# 0.910958904109589

# %%
x = 0
for(x, value) in enumerate(score):
    print(f"{x} qestion 5 "
        f"{value:.3f} and question 6 "
        f"{scores6[x]:.3f}"
        " result is " f"{value-scores6[x]:.3f}")
    x = x + 1
# Out:
# 0 qestion 5 0.911 and question6 0.952 result is -0.041
# 1 qestion 5 0.890 and question6 0.911 result is -0.021
# 2 qestion 5 0.911 and question6 0.904 result is 0.007
# 3 qestion 5 0.884 and question6 0.925 result is -0.041
# 4 qestion 5 0.904 and question6 0.890 result is 0.014
# 5 qestion 5 0.884 and question6 0.959 result is -0.075
# 6 qestion 5 0.884 and question6 0.877 result is 0.007
# 7 qestion 5 0.877 and question6 0.890 result is -0.014
# 8 qestion 5 0.897 and question6 0.945 result is -0.048
# 9 qestion 5 0.877 and question6 0.904 result is -0.027
